# %%
import requests
import bs4 as bs

# %%
res = requests.get('https://en.wikipedia.org/wiki/Forever_Living_Products')

# %%
soup = bs.BeautifulSoup(res.text, 'lxml')

# %%
for link in soup.find_all('a'):
      print(link)
# Out:
# <a id="top"></a>
# <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# <a class="mw-jump-link" href="#searchInput">Jump to search</a>
# <a class="image" href="/wiki/File:Foreverlivingproducts_logo.jpg"><img alt="Foreverlivingproducts logo.jpg" data-file-height="49" data-file-width="219" decoding="async" height="49" src="//upload.wikimedia.org/wikipedia/en/2/2c/Foreverlivingproducts_logo.jpg" width="220"/></a>
# <a href="/wiki/Multi-level_marketing" title="Multi-level marketing">Multi-level marketing</a>
# <a href="/wiki/Rex_Maughan" title="Rex Maughan">Rex Maughan</a>
# <a href="/wiki/Scottsdale,_Arizona" title="Scottsdale, Arizona">Scottsdale, Arizona</a>
# <a href="/wiki/United_States" title="United States">United States</a>
# <a href="/wiki/Aloe_vera" title="Aloe vera">Aloe vera</a>
# <a href="/wiki/Bee" title="Bee">bee</a>
# <a href="/wiki/Subsidiary" title="Subsidiary">Subsidiaries</a>
# ...

# %%
import urllib

# %%
link = 'https://en.wikipedia.org/wiki/Forever_Living_Products'

# %%
Link = urllib.request.urlopen(link).read()

# %%
Link
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Forever Living Products - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"070cf771-aa2d-45c0-b424-344584cea3e3","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Forever_Living_Products","wgTitle":"Forever Living Products","wgCurRevisionId":982635696,"wgRevisionId":982635696,"wgArticleId":2124647,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with short description","Short description with empty Wikidata description","Use mdy dates from April 2017","All articles
# ...
